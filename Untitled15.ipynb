# %% [markdown]
# <a href="https://colab.research.google.com/github/eldusastig/EMTECH-2/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name:** Jethro B Duque |
# **Section:** CPE32S9

# %% [markdown]
# # 1 Import the Libraries and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
data1="/content/titanic_test.csv"
data2="/content/titanic_train.csv"
data1_frame= pd.read_csv(data1)
data2_frame= pd.read_csv(data2)

# %%
data1_frame.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['PassengerId'].plot(kind='hist', bins=20, title='PassengerId')
# ...

# %%
data2_frame.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %% [markdown]
# #  2. Plot the Data

# %%
maleDf1=data1_frame[(data1_frame.Sex=="male")]
maleDf2=data2_frame[(data2_frame.Sex=="male")]
femaleDf1=data1_frame[(data1_frame.Sex=="female")]
femaleDf2=data2_frame[(data2_frame.Sex=="female")]

# %%
men=pd.concat([maleDf1,maleDf2])
mean=men[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
plt.scatter(mean,men["Age"])
plt.ylabel('Age')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-9d4e208ce4bc> in <cell line: 4>()
#       2 mean=men[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
#       3 plt.scatter(mean,men["Age"])
# ----> 4 plt.ylabel('Age')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
mean=men[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
plt.scatter(mean,men["Fare"])
plt.xlabel="mean"
plt.ylabel="Fare"
plt.show()

# %%
mean=men[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
plt.scatter(mean,men['SibSp'])
plt.xlabel('mean')
plt.ylabel('SibSp')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-5f0d17ecd0e2> in <cell line: 3>()
#       1 mean=men[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
#       2 plt.scatter(mean,men['SibSp'])
# ----> 3 plt.xlabel('mean')
#       4 plt.ylabel('SibSp')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
mean=men[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
plt.scatter(mean,men["Parch"])
plt.xlabel('mean')
plt.ylabel('SibSp')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-508def4dbe3a> in <cell line: 3>()
#       1 mean=men[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
#       2 plt.scatter(mean,men["Parch"])
# ----> 3 plt.xlabel('mean')
#       4 plt.ylabel('SibSp')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
female=pd.concat([femaleDf1,femaleDf2])
meanf=female[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
plt.scatter(meanf,female["Age"])
plt.show()

# %%
female=pd.concat([femaleDf1,femaleDf2])
meanf=female[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
plt.scatter(meanf,female["Pclass"])
plt.show()

# %%
meanf=female[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
plt.scatter(meanf,female["SibSp"])
plt.show()

# %%
female=pd.concat([femaleDf1,femaleDf2])
meanf=female[["Pclass","Age","SibSp","Parch"]].mean(axis=1)
plt.scatter(meanf,female["Parch"])
plt.show()

# %% [markdown]
# # 3.Perform Simple Linear Regression on the SURVIVAL feature column (you can check the internet on how you can perform simple linear regression)

# %%
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression
