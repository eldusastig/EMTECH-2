# %% [markdown]
# <a href="https://colab.research.google.com/github/eldusastig/EMTECH-2/blob/main/Hands_on_Activity_3_1_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME:**Jethro B Duque** <br>
# COURSE & SECTION: **CPE019-CPE32S9** <br>
# DATE:**2/7/2024**

# %%
import pandas as pd
import matplotlib.pyplot as plt

brainFrame= pd.read_csv("/brainsize.txt",sep='\t')

# %%
brainFrame.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0  Female   133  132  124   118.0    64.5     816932
# 1    Male   140  150  124     NaN    72.5    1001121
# 2    Male   139  123  150   143.0    73.3    1038437
# 3    Male   133  129  128   172.0    68.8     965353
# 4  Female   137  132  134   147.0    65.0     951545

# %%
brainFrame.tail()
# Out:
#     Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 35  Female   133  129  128   153.0    66.5     948066
# 36    Male   140  150  124   144.0    70.5     949395
# 37  Female    88   86   94   139.0    64.5     893983
# 38    Male    81   90   74   148.0    74.0     930016
# 39    Male    89   91   89   179.0    75.5     935863

# %%
brainFrame.describe()
# Out:
#              FSIQ         VIQ        PIQ      Weight     Height     MRI_Count
# count   40.000000   40.000000   40.00000   38.000000  39.000000  4.000000e+01
# mean   113.450000  112.350000  111.02500  151.052632  68.525641  9.087550e+05
# std     24.082071   23.616107   22.47105   23.478509   3.994649  7.228205e+04
# min     77.000000   71.000000   72.00000  106.000000  62.000000  7.906190e+05
# 25%     89.750000   90.000000   88.25000  135.250000  66.000000  8.559185e+05
# 50%    116.500000  113.000000  115.00000  146.500000  68.000000  9.053990e+05
# 75%    135.500000  129.750000  128.00000  172.000000  70.500000  9.500780e+05
# max    144.000000  150.000000  150.00000  192.000000  77.000000  1.079549e+06

# %%
menDf= brainFrame[(brainFrame.Gender=='Male')]
womenDf= brainFrame[(brainFrame.Gender=='Female')]

# %%
menMeanSmarts = menDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(menMeanSmarts, menDf["MRI_Count"])
plt.show()
# %matplotlib inline

# %%
femaleMeanSmarts = womenDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(femaleMeanSmarts, womenDf["MRI_Count"])
plt.show()
# %matplotlib inline

# %%
brainFrame.corr(method='pearson')
# Out:
# <ipython-input-25-4d3089cc6357>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   brainFrame.corr(method='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.946639  0.934125 -0.051483 -0.086002   0.357641
# VIQ        0.946639  1.000000  0.778135 -0.076088 -0.071068   0.337478
# PIQ        0.934125  0.778135  1.000000  0.002512 -0.076723   0.386817
# Weight    -0.051483 -0.076088  0.002512  1.000000  0.699614   0.513378
# Height    -0.086002 -0.071068 -0.076723  0.699614  1.000000   0.601712
# MRI_Count  0.357641  0.337478  0.386817  0.513378  0.601712   1.000000

# %% [markdown]
# **Notice at the left-to-right diagonal in the correlation table generated above. Why is the diagonal filled
# with 1s? Is that a coincidence? Explain**

# %% [markdown]
# - It's just means that the variable is correlated to itself.

# %%
womenDf.corr(method='pearson')
# Out:
# <ipython-input-36-01fad84dd5db>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   womenDf.corr(method='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.955717  0.939382  0.038192 -0.059011   0.325697
# VIQ        0.955717  1.000000  0.802652 -0.021889 -0.146453   0.254933
# PIQ        0.939382  0.802652  1.000000  0.113901 -0.001242   0.396157
# Weight     0.038192 -0.021889  0.113901  1.000000  0.552357   0.446271
# Height    -0.059011 -0.146453 -0.001242  0.552357  1.000000   0.174541
# MRI_Count  0.325697  0.254933  0.396157  0.446271  0.174541   1.000000

# %%
menDf.corr(method='pearson')
# Out:
# <ipython-input-37-4396b7a1db7e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   menDf.corr(method='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.944400  0.930694 -0.278140 -0.356110   0.498369
# VIQ        0.944400  1.000000  0.766021 -0.350453 -0.355588   0.413105
# PIQ        0.930694  0.766021  1.000000 -0.156863 -0.287676   0.568237
# Weight    -0.278140 -0.350453 -0.156863  1.000000  0.406542  -0.076875
# Height    -0.356110 -0.355588 -0.287676  0.406542  1.000000   0.301543
# MRI_Count  0.498369  0.413105  0.568237 -0.076875  0.301543   1.000000

# %%
# !pip install seaborn

# %%
import seaborn as sns
wcorr= womenDf.corr()
sns.heatmap(wcorr)
# Out:
# <ipython-input-35-b29bb7740611>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   wcorr= womenDf.corr()
# <Axes: >

# %%
mcorr=menDf.corr()
sns.heatmap(mcorr)
# Out:
# <ipython-input-34-4237012c4b96>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mcorr=menDf.corr()
# <Axes: >

# %% [markdown]
# **Many variable pairs present correlation close to zero. What does that mean?
# Why separate the genders?**

# %% [markdown]
# - If the pairs are close to zero, it means that there is no or weak correlation between the two. We separated the gender to know if there's a differene between men and women.

# %% [markdown]
# **What variables have stronger correlation with brain size (MRI_Count)? Is that expected? Explain.**

# %% [markdown]
# The PIQ has a strong correlation  with MRI_count. Yes, becasue more brain mass means that there is more computing power for the brain

# %% [markdown]
# # SUPPLEMENTARY ACTIVITY

# %% [markdown]
# look for (any) real-world dataset and perform exploratory and statistical analysis.

# %%
carFrame=pd.read_excel('/Cars.xls')

# %%
carFrame['REG'].unique()
# Out:
# array(['USA', 'Asia', 'Eur', 'Aust'], dtype=object)

# %%
usaDf= carFrame[(carFrame.REG=='USA')]
asiaDf= carFrame[(carFrame.REG=='Asia')]
euDf= carFrame[(carFrame.REG=='Eur')]
austDf= carFrame[(carFrame.REG=='Aust')]

# %%
carFrame.corr(method='pearson')
# Out:
# <ipython-input-54-4cb542cd4758>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   carFrame.corr(method='pearson')
#            DOORS       ENG    WEIGHT     PRICE
# DOORS   1.000000 -0.042964 -0.132303 -0.384861
# ENG    -0.042964  1.000000  0.738288  0.409359
# WEIGHT -0.132303  0.738288  1.000000  0.624510
# PRICE  -0.384861  0.409359  0.624510  1.000000

# %%
usaDf.corr(method='pearson')
# Out:
# <ipython-input-56-6580318979f5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   usaDf.corr(method='pearson')
#            DOORS       ENG    WEIGHT     PRICE
# DOORS   1.000000 -0.063872  0.038441  0.181054
# ENG    -0.063872  1.000000  0.826710  0.852841
# WEIGHT  0.038441  0.826710  1.000000  0.878987
# PRICE   0.181054  0.852841  0.878987  1.000000

# %%
asiaDf.corr(method='pearson')
# Out:
# <ipython-input-57-92fd4651ea53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   asiaDf.corr(method='pearson')
#            DOORS       ENG    WEIGHT     PRICE
# DOORS   1.000000  0.211560  0.185009  0.151606
# ENG     0.211560  1.000000  0.801906  0.594098
# WEIGHT  0.185009  0.801906  1.000000  0.610000
# PRICE   0.151606  0.594098  0.610000  1.000000

# %%
euDf.corr(method='pearson')
# Out:
# <ipython-input-58-92fd4651ea53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   asiaDf.corr(method='pearson')
#            DOORS       ENG    WEIGHT     PRICE
# DOORS   1.000000  0.211560  0.185009  0.151606
# ENG     0.211560  1.000000  0.801906  0.594098
# WEIGHT  0.185009  0.801906  1.000000  0.610000
# PRICE   0.151606  0.594098  0.610000  1.000000

# %%
austDf.corr(method='pearson')
# Out:
# <ipython-input-59-169515cc16e3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   austDf.corr(method='pearson')
#            DOORS       ENG    WEIGHT     PRICE
# DOORS   1.000000  0.101963  0.167639  0.186560
# ENG     0.101963  1.000000  0.966598  0.952205
# WEIGHT  0.167639  0.966598  1.000000  0.971359
# PRICE   0.186560  0.952205  0.971359  1.000000

# %%
usacorr= usaDf.corr()
sns.heatmap(usacorr)
# Out:
# <ipython-input-60-d5908807b1e0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   usacorr= usaDf.corr()
# <Axes: >

# %%
asiacorr= asiaDf.corr()
sns.heatmap(asiacorr)
# Out:
# <ipython-input-61-50f561d07354>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   asiacorr= asiaDf.corr()
# <Axes: >

# %%
eucorr= euDf.corr()
sns.heatmap(eucorr)
# Out:
# <ipython-input-62-ba131f062a37>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   eucorr= euDf.corr()
# <Axes: >

# %%
austcorr= austDf.corr()
sns.heatmap(austcorr)
# Out:
# <ipython-input-63-dae8fd251175>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   austcorr= austDf.corr()
# <Axes: >

# %%
carcorr= carFrame.corr()
sns.heatmap(carcorr)
# Out:
# <ipython-input-67-398524320866>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   carcorr= carFrame.corr()
# <Axes: >

# %% [markdown]
# - The data shows us the correlation of the price the car with different physical  characteristics relative to its manufacturer's region.

# %% [markdown]
# # Conclusion

# %% [markdown]
# - In this activity, I learned the different ways we can analyze and show  data with the use of numpy, panda and seaborn. Learning the usage of the library is important, because it let's use analyze big data much faster and effiecient instead of computing them manually.
